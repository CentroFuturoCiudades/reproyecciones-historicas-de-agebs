# %%
import os
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt

# %% [markdown]
# ## 1. Carga de Datos
# ### 1.1 Malla Geoestadística

# %%
path_data = "../../Sample_Data/Raw/"
malla_path = path_data + "malla_geoestadistica/conjunto_de_datos/nivel8.shp"
malla_geo  = gpd.read_file(malla_path)

# %%
malla_geo.crs
# Out:
# <Geographic 2D CRS: EPSG:6365>
# Name: Mexico ITRF2008
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: Mexico - onshore and offshore.
# - bounds: (-122.19, 12.1, -84.64, 32.72)
# Datum: Mexico ITRF2008
# - Ellipsoid: GRS 1980
# - Prime Meridian: Greenwich

# %%
malla_geo.head()
# Out:
#       codigo                                           geometry
# 0  O28545334  POLYGON ((-91.46776 17.27761, -91.45405 17.277...
# 1  O28545335  POLYGON ((-91.45405 17.27761, -91.44033 17.277...
# 2  O28545343  POLYGON ((-91.44033 17.27761, -91.42661 17.277...
# 3  O28545344  POLYGON ((-91.42661 17.27761, -91.41289 17.277...
# 4  O28545345  POLYGON ((-91.41289 17.27761, -91.39918 17.277...

# %%
malla_geo = malla_geo.to_crs(agebs_2020.crs)

# %% [markdown]
# ### 1.2 Censo 2000

# %%
agebs_2000_path = path_data + "agebs_2000/NACIONAL/N_Agebs_0000_01.shp"
agebs_2000  = gpd.read_file(agebs_2000_path)

# %%
agebs_2000.crs
# Out:
# <Projected CRS: PROJCS["North_America_Lambert_Conformal_Conic",GEO ...>
# Name: North_America_Lambert_Conformal_Conic
# Axis Info [cartesian]:
# - [east]: Easting (metre)
# - [north]: Northing (metre)
# Area of Use:
# - undefined
# Coordinate Operation:
# - name: unnamed
# - method: Lambert Conic Conformal (2SP)
# Datum: North American Datum 1927 (CGQ77)
# - Ellipsoid: Clarke 1866
# - Prime Meridian: Greenwich

# %%
agebs_2000
# Out:
#       CVE_EDO CVE_MUN    CVE_LOC        CVE_AGEB   AGEB         NOM_EDO  \
# 0          23   23008  230080323  230080323061-6  061-6    QUINTANA ROO
# 1          23   23008  230080323  230080323060-1  060-1    QUINTANA ROO
# 2          23   23008  230080323  230080323074-3  074-3    QUINTANA ROO
# 3          23   23008  230080323  230080323056-5  056-5    QUINTANA ROO
# 4          23   23008  230080323  230080323057-A  057-A    QUINTANA ROO
# ...       ...     ...        ...             ...    ...             ...
# 40084      01   01001  010010001  010010001256-4  256-4  AGUASCALIENTES
# 40085      01   01001  010010001  010010001284-6  284-6  AGUASCALIENTES
# 40086      01   01001  010010001  010010001255-A  255-A  AGUASCALIENTES
# 40087      01   01001  010010001  010010001252-6  252-6  AGUASCALIENTES
# 40088      01   01001  010010001  010010001251-1  251-1  AGUASCALIENTES
#
#       ABRE_EDO         NOM_MUN         NOM_LOC      Z1  ...     I6     I7  \
# ...

# %%
censo_2000_path = path_data + "agebs_2000/censo2000.geojson"
censo_2000  = gpd.read_file(censo_2000_path)

# %%
censo_2000.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World.
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
censo_2000 = agebs_2000.copy()
censo_2000.head()
# Out:
#   CVE_EDO CVE_MUN    CVE_LOC        CVE_AGEB   AGEB       NOM_EDO ABRE_EDO  \
# 0      23   23008  230080323  230080323061-6  061-6  QUINTANA ROO    Q ROO
# 1      23   23008  230080323  230080323060-1  060-1  QUINTANA ROO    Q ROO
# 2      23   23008  230080323  230080323074-3  074-3  QUINTANA ROO    Q ROO
# 3      23   23008  230080323  230080323056-5  056-5  QUINTANA ROO    Q ROO
# 4      23   23008  230080323  230080323057-A  057-A  QUINTANA ROO    Q ROO
#
#        NOM_MUN NOM_LOC      Z1  ...     I6     I7     I8     I9    I10    I11  \
# 0  SOLIDARIDAD   TULUM    42.0  ...    NaN    NaN    NaN    NaN    NaN    NaN
# 1  SOLIDARIDAD   TULUM   173.0  ...  91.18  79.41  76.47  58.82  50.00   0.00
# 2  SOLIDARIDAD   TULUM     0.0  ...    NaN    NaN    NaN    NaN    NaN    NaN
# 3  SOLIDARIDAD   TULUM  1519.0  ...  64.19  48.01  49.87  46.68  37.82   3.74
# 4  SOLIDARIDAD   TULUM  1152.0  ...  69.96  46.25  49.01  46.25  40.18  11.39
#
# ...

# %%
censo_2000 = censo_2000.to_crs(agebs_2020.crs)

# %%
gdl_2000 = censo_2000[censo_2000.NOM_MUN == "GUADALAJARA"].rename(columns={'Z1': 'pobtot'}).reset_index(drop = True)
gdl_2000.dropna(inplace = True)
gdl_2000
# Out:
#     CVE_EDO CVE_MUN    CVE_LOC        CVE_AGEB   AGEB  NOM_EDO ABRE_EDO  \
# 0        14   14039  140390001  140390001300-1  300-1  JALISCO      JAL
# 2        14   14039  140390001  140390001379-8  379-8  JALISCO      JAL
# 3        14   14039  140390001  140390001483-2  483-2  JALISCO      JAL
# 4        14   14039  140390001  140390001376-4  376-4  JALISCO      JAL
# 5        14   14039  140390001  140390001286-A  286-A  JALISCO      JAL
# ..      ...     ...        ...             ...    ...      ...      ...
# 432      14   14039  140390001  140390001392-3  392-3  JALISCO      JAL
# 433      14   14039  140390001  140390001437-2  437-2  JALISCO      JAL
# 434      14   14039  140390001  140390001390-4  390-4  JALISCO      JAL
# 435      14   14039  140390001  140390001358-6  358-6  JALISCO      JAL
# 436      14   14039  140390001  140390001302-0  302-0  JALISCO      JAL
#
#          NOM_MUN      NOM_LOC  pobtot  ...     I6     I7     I8     I9    I10  \
# ...

# %%
mid_2000 = censo_2000[censo_2000.NOM_MUN == "MERIDA"].rename(columns={'Z1': 'pobtot'}).reset_index(drop = True)
mid_2000.dropna(inplace = True)
mid_2000
# Out:
#     CVE_EDO CVE_MUN    CVE_LOC        CVE_AGEB   AGEB  NOM_EDO ABRE_EDO  \
# 0        31   31050  310500111  310500111440-5  440-5  YUCATAN      YUC
# 2        31   31050  310500093  310500093212-7  212-7  YUCATAN      YUC
# 3        31   31050  310500093  310500093211-2  211-2  YUCATAN      YUC
# 6        31   31050  310500084  310500084218-4  218-4  YUCATAN      YUC
# 7        31   31050  310500084  310500084219-9  219-9  YUCATAN      YUC
# ..      ...     ...        ...             ...    ...      ...      ...
# 313      31   31050  310500001  310500001411-9  411-9  YUCATAN      YUC
# 314      31   31050  310500001  310500001025-8  025-8  YUCATAN      YUC
# 315      31   31050  310500001  310500001017-3  017-3  YUCATAN      YUC
# 316      31   31050  310500001  310500001018-8  018-8  YUCATAN      YUC
# 317      31   31050  310500001  310500001406-8  406-8  YUCATAN      YUC
#
#     NOM_MUN        NOM_LOC  pobtot  ...     I6     I7     I8     I9    I10  \
# ...

# %%
mty_2000 = censo_2000[censo_2000.NOM_MUN == "MONTERREY"].rename(columns={'Z1': 'pobtot'}).reset_index(drop = True)
mty_2000.dropna(inplace = True)
mty_2000
# Out:
#     CVE_EDO CVE_MUN    CVE_LOC        CVE_AGEB   AGEB     NOM_EDO ABRE_EDO  \
# 1        19   19039  190390001  190390001006-7  006-7  NUEVO LEON       NL
# 2        19   19039  190390001  190390001262-7  262-7  NUEVO LEON       NL
# 3        19   19039  190390001  190390001407-4  407-4  NUEVO LEON       NL
# 4        19   19039  190390001  190390001011-8  011-8  NUEVO LEON       NL
# 5        19   19039  190390001  190390001405-5  405-5  NUEVO LEON       NL
# ..      ...     ...        ...             ...    ...         ...      ...
# 409      19   19039  190390001  190390001404-0  404-0  NUEVO LEON       NL
# 410      19   19039  190390001  190390001337-7  337-7  NUEVO LEON       NL
# 411      19   19039  190390001  190390001340-9  340-9  NUEVO LEON       NL
# 412      19   19039  190390001  190390001338-1  338-1  NUEVO LEON       NL
# 413      19   19039  190390001  190390001336-2  336-2  NUEVO LEON       NL
#
# ...

# %% [markdown]
# ### 1.3 Censo 2010

# %%
agebs_2010_path = path_data + "agebs_2010/AGEB_urb_2010_5.shp"
agebs_2010  = gpd.read_file(agebs_2010_path)

# %%
agebs_2010.head()
# Out:
#     CODIGO         CVEGEO                  GEOGRAFICO FECHAACT GEOMETRIA  \
# 0  LA_6052  0100100013204  ÁREA GEOESTADÍSTICA BÁSICA  12/2007      ÁREA
# 1  LA_6052  0100100013721  ÁREA GEOESTADÍSTICA BÁSICA  12/2007      ÁREA
# 2  LA_6052  0100100010657  ÁREA GEOESTADÍSTICA BÁSICA  12/2007      ÁREA
# 3  LA_6052  0100100011528  ÁREA GEOESTADÍSTICA BÁSICA  12/2007      ÁREA
# 4  LA_6052  0100100011674  ÁREA GEOESTADÍSTICA BÁSICA  12/2007      ÁREA
#
#   INSTITUCIO  OID                                           geometry
# 0      INEGI    1  POLYGON ((2475018.434 1098724.434, 2475012.982...
# 1      INEGI    2  POLYGON ((2475469.244 1098964.293, 2475431.454...
# 2      INEGI    3  POLYGON ((2470787.576 1096193.647, 2470787.327...
# 3      INEGI    4  POLYGON ((2470709.683 1097766.390, 2470705.629...
# 4      INEGI    5  POLYGON ((2466998.954 1095069.117, 2467001.023...

# %%
agebs_2010 = agebs_2010.to_crs(censo_2000.crs)

# %%
agebs_2010['CVE_ENT'] = agebs_2010['CVEGEO'].str[:2]
agebs_2010['CVE_MUN'] = agebs_2010['CVEGEO'].str[2:5]
agebs_2010
# Out:
#         CODIGO         CVEGEO                  GEOGRAFICO FECHAACT GEOMETRIA  \
# 0      LA_6052  0100100013204  ÁREA GEOESTADÍSTICA BÁSICA  12/2007      ÁREA
# 1      LA_6052  0100100013721  ÁREA GEOESTADÍSTICA BÁSICA  12/2007      ÁREA
# 2      LA_6052  0100100010657  ÁREA GEOESTADÍSTICA BÁSICA  12/2007      ÁREA
# 3      LA_6052  0100100011528  ÁREA GEOESTADÍSTICA BÁSICA  12/2007      ÁREA
# 4      LA_6052  0100100011674  ÁREA GEOESTADÍSTICA BÁSICA  12/2007      ÁREA
# ...        ...            ...                         ...      ...       ...
# 56190  LA_6052  3205800010087  ÁREA GEOESTADÍSTICA BÁSICA  06/2009      ÁREA
# 56191  LA_6052  3205800010104  ÁREA GEOESTADÍSTICA BÁSICA  06/2009      ÁREA
# 56192  LA_6052  320580001002A  ÁREA GEOESTADÍSTICA BÁSICA  12/2007      ÁREA
# 56193  LA_6052  3205800010015  ÁREA GEOESTADÍSTICA BÁSICA  12/2007      ÁREA
# 56194  LA_6052  3205800010072  ÁREA GEOESTADÍSTICA BÁSICA  12/2007      ÁREA
#
# ...

# %%
censo_2010_path = path_data + "censo_2010/"
xls_files = [file for file in os.listdir(censo_2010_path) if file.endswith(".csv")]
print(xls_files)
censo_2010 = pd.DataFrame()

for xls_file in xls_files:
    file_path = os.path.join(censo_2010_path, xls_file)
    temp_df = pd.read_csv(file_path)
    censo_2010 = pd.concat([censo_2010, temp_df], ignore_index=True)
# Out:
# ['RESAGEBURB_25XLS10.csv', 'RESAGEBURB_26XLS10_1.csv', 'RESAGEBURB_26XLS10_2.csv', 'RESAGEBURB_14XLS10_2.csv', 'RESAGEBURB_19XLS10_1.csv', 'RESAGEBURB_14XLS10_1.csv', 'RESAGEBURB_19XLS10_2.csv', 'RESAGEBURB_22XLS10.csv', 'RESAGEBURB_31XLS10.csv']

# %%
censo_2010
# Out:
#         ENTIDAD  NOM_ENT  MUN                       NOM_MUN  LOC  \
# 0            25  Sinaloa    0  Total de la entidad  Sinaloa    0
# 1            25  Sinaloa    1                         Ahome    0
# 2            25  Sinaloa    1                         Ahome    1
# 3            25  Sinaloa    1                         Ahome    1
# 4            25  Sinaloa    1                         Ahome    1
# ...         ...      ...  ...                           ...  ...
# 313319       31  Yucatán  106                        Yobaín    1
# 313320       31  Yucatán  106                        Yobaín    1
# 313321       31  Yucatán  106                        Yobaín    1
# 313322       31  Yucatán  106                        Yobaín    1
# 313323       31  Yucatán  106                        Yobaín    1
#
#                              NOM_LOC  AGEB  MZA   POBTOT   POBMAS  ...  \
# 0                Total de la entidad  0000    0  2767761  1376201  ...
# ...

# %%
# Asegurarse de que las columnas tengan el formato deseado
censo_2010['ENTIDAD'] = censo_2010['ENTIDAD'].apply(lambda x: f'{x:02d}')
censo_2010['MUN'] = censo_2010['MUN'].apply(lambda x: f'{x:03d}')
censo_2010['LOC'] = censo_2010['LOC'].apply(lambda x: f'{x:04d}')

# Concatenar las columnas en una sola columna "CVEGEO"
censo_2010['CVEGEO'] = censo_2010['ENTIDAD'] + censo_2010['MUN'] + censo_2010['LOC'] + censo_2010['AGEB']
censo_2010_filtered = censo_2010[censo_2010["MZA"]==0][["CVEGEO", "POBTOT"]]
censo_2010_filtered
# Out:
#                CVEGEO   POBTOT
# 0       2500000000000  2767761
# 1       2500100000000   416299
# 2       2500100010000   256613
# 3       2500100010012     1149
# 36      2500100010027     2245
# ...               ...      ...
# 313235  3110600000000     2137
# 313236  3110600010000     1820
# 313237  3110600010043      998
# 313284  3110600010058      815
# 313322  3110600010077        7
#
# [14140 rows x 2 columns]

# %%
gdl_2010 = agebs_2010.loc[(agebs_2010.CVE_ENT == "14") & (agebs_2010.CVE_MUN == "039")].copy()
gdl_2010 = gdl_2010.merge(censo_2010_filtered, on='CVEGEO', how='left')
gdl_2010 = gdl_2010.rename(columns={'POBTOT': 'pobtot'}).reset_index(drop=True)
gdl_2010.dropna(inplace=True)
gdl_2010
# Out:
#       CODIGO         CVEGEO                  GEOGRAFICO FECHAACT GEOMETRIA  \
# 0    LA_6052  1403900014777  ÁREA GEOESTADÍSTICA BÁSICA  12/2007      ÁREA
# 1    LA_6052  1403900015046  ÁREA GEOESTADÍSTICA BÁSICA  12/2007      ÁREA
# 2    LA_6052  1403900014508  ÁREA GEOESTADÍSTICA BÁSICA  12/2007      ÁREA
# 3    LA_6052  1403900013942  ÁREA GEOESTADÍSTICA BÁSICA  12/2007      ÁREA
# 4    LA_6052  1403900014071  ÁREA GEOESTADÍSTICA BÁSICA  12/2007      ÁREA
# ..       ...            ...                         ...      ...       ...
# 437  LA_6052  1403900013482  ÁREA GEOESTADÍSTICA BÁSICA  12/2007      ÁREA
# 438  LA_6052  1403900013590  ÁREA GEOESTADÍSTICA BÁSICA  12/2007      ÁREA
# 439  LA_6052  1403900013923  ÁREA GEOESTADÍSTICA BÁSICA  12/2007      ÁREA
# 440  LA_6052  1403900010399  ÁREA GEOESTADÍSTICA BÁSICA  12/2007      ÁREA
# 441  LA_6052  1403900014809  ÁREA GEOESTADÍSTICA BÁSICA  12/2007      ÁREA
#
# ...

# %%
mid_2010 = agebs_2010.loc[(agebs_2010.CVE_ENT == "31") & (agebs_2010.CVE_MUN == "050")].copy()
mid_2010 = mid_2010.merge(censo_2010_filtered, on='CVEGEO', how='left')
mid_2010 = mid_2010.rename(columns={'POBTOT': 'pobtot'}).reset_index(drop=True)
mid_2010.dropna(inplace=True)
mid_2010
# Out:
#       CODIGO         CVEGEO                  GEOGRAFICO FECHAACT GEOMETRIA  \
# 0    LA_6052  310500001516A  ÁREA GEOESTADÍSTICA BÁSICA  12/2007      ÁREA
# 1    LA_6052  3105000012625  ÁREA GEOESTADÍSTICA BÁSICA  12/2007      ÁREA
# 2    LA_6052  3105000012697  ÁREA GEOESTADÍSTICA BÁSICA  12/2007      ÁREA
# 3    LA_6052  3105000013572  ÁREA GEOESTADÍSTICA BÁSICA  12/2007      ÁREA
# 4    LA_6052  3105000015649  ÁREA GEOESTADÍSTICA BÁSICA  12/2007      ÁREA
# ..       ...            ...                         ...      ...       ...
# 469  LA_6052  3105001116276  ÁREA GEOESTADÍSTICA BÁSICA  09/2010      ÁREA
# 470  LA_6052  3105001116280  ÁREA GEOESTADÍSTICA BÁSICA  09/2010      ÁREA
# 471  LA_6052  3105001116295  ÁREA GEOESTADÍSTICA BÁSICA  09/2010      ÁREA
# 472  LA_6052  3105004086596  ÁREA GEOESTADÍSTICA BÁSICA  06/2010      ÁREA
# 473  LA_6052  3105004086609  ÁREA GEOESTADÍSTICA BÁSICA  06/2010      ÁREA
#
# ...

# %%
mty_2010 = agebs_2010.loc[(agebs_2010.CVE_ENT == "19") & (agebs_2010.CVE_MUN == "039")].copy()
mty_2010 = mty_2010.merge(censo_2010_filtered, on='CVEGEO', how='left')
mty_2010 = mty_2010.rename(columns={'POBTOT': 'pobtot'}).reset_index(drop=True)
mty_2010.dropna(inplace=True)
mty_2010
# Out:
#       CODIGO         CVEGEO                  GEOGRAFICO FECHAACT GEOMETRIA  \
# 0    LA_6052  1903900010832  ÁREA GEOESTADÍSTICA BÁSICA  12/2007      ÁREA
# 1    LA_6052  1903900011826  ÁREA GEOESTADÍSTICA BÁSICA  12/2007      ÁREA
# 2    LA_6052  1903900012468  ÁREA GEOESTADÍSTICA BÁSICA  12/2007      ÁREA
# 3    LA_6052  190390001185A  ÁREA GEOESTADÍSTICA BÁSICA  12/2007      ÁREA
# 4    LA_6052  1903900012951  ÁREA GEOESTADÍSTICA BÁSICA  12/2007      ÁREA
# ..       ...            ...                         ...      ...       ...
# 460  LA_6052  1903900012788  ÁREA GEOESTADÍSTICA BÁSICA  12/2007      ÁREA
# 461  LA_6052  190390001274A  ÁREA GEOESTADÍSTICA BÁSICA  12/2007      ÁREA
# 462  LA_6052  1903900011760  ÁREA GEOESTADÍSTICA BÁSICA  12/2007      ÁREA
# 463  LA_6052  1903900014873  ÁREA GEOESTADÍSTICA BÁSICA  12/2007      ÁREA
# 464  LA_6052  1903900012932  ÁREA GEOESTADÍSTICA BÁSICA  12/2007      ÁREA
#
# ...

# %% [markdown]
# ### 1.4 Censo 2020

# %%
agebs_2020_path = path_data + "agebs_2020/mg_2020_integrado/conjunto_de_datos/00a.shp"
agebs_2020  = gpd.read_file(agebs_2020_path)

# %%
agebs_2020.head()
# Out:
#           CVEGEO CVE_ENT CVE_MUN CVE_LOC CVE_AGEB  Ambito  \
# 0  010060001009A      01     006    0001     009A  Urbana
# 1  0100600010244      01     006    0001     0244  Urbana
# 2  0100600010140      01     006    0001     0140  Urbana
# 3  0100600010278      01     006    0001     0278  Urbana
# 4  0100600010070      01     006    0001     0070  Urbana
#
#                                             geometry
# 0  POLYGON ((2471856.117 1124829.239, 2471859.442...
# 1  POLYGON ((2472405.057 1126442.149, 2472346.028...
# 2  POLYGON ((2470824.629 1124721.867, 2470816.835...
# 3  POLYGON ((2471872.403 1124426.252, 2471869.144...
# 4  POLYGON ((2471843.929 1124789.995, 2471846.977...

# %%
agebs_2020.crs
# Out:
# <Projected CRS: PROJCS["MEXICO_ITRF_2008_LCC",GEOGCS["MEXICO_ITRF_ ...>
# Name: MEXICO_ITRF_2008_LCC
# Axis Info [cartesian]:
# - [east]: Easting (metre)
# - [north]: Northing (metre)
# Area of Use:
# - undefined
# Coordinate Operation:
# - name: unnamed
# - method: Lambert Conic Conformal (2SP)
# Datum: International Terrestrial Reference Frame 2008
# - Ellipsoid: GRS 1980
# - Prime Meridian: Greenwich

# %%
agebs_2020 = agebs_2020.to_crs(agebs_2020.crs)

# %%
censo_2020_path = path_data + "censo_2020/"
csv_files = [file for file in os.listdir(censo_2020_path) if file.endswith(".csv")]

censo_2020 = pd.DataFrame()

for csv_file in csv_files:
    file_path = os.path.join(censo_2020_path, csv_file)
    temp_df = pd.read_csv(file_path)
    censo_2020 = pd.concat([censo_2020, temp_df], ignore_index=True)

# %%
censo_2020[censo_2020.NOM_MUN == "Mazatlán"]
# Out:
#        ENTIDAD  NOM_ENT  MUN   NOM_MUN   LOC                       NOM_LOC  \
# 362199      25  Sinaloa  012  Mazatlán  0000           Total del municipio
# 362200      25  Sinaloa  012  Mazatlán  0001  Total de la localidad urbana
# 362201      25  Sinaloa  012  Mazatlán  0001             Total AGEB urbana
# 362202      25  Sinaloa  012  Mazatlán  0001                      Mazatlán
# 362203      25  Sinaloa  012  Mazatlán  0001                      Mazatlán
# ...        ...      ...  ...       ...   ...                           ...
# 371235      25  Sinaloa  012  Mazatlán  1257   Fraccionamiento los Ángeles
# 371236      25  Sinaloa  012  Mazatlán  1257             Total AGEB urbana
# 371237      25  Sinaloa  012  Mazatlán  1257   Fraccionamiento los Ángeles
# 371238      25  Sinaloa  012  Mazatlán  1257             Total AGEB urbana
# 371239      25  Sinaloa  012  Mazatlán  1257   Fraccionamiento los Ángeles
#
# ...

# %%
# Asegurarse de que las columnas tengan el formato deseado
censo_2020['ENTIDAD'] = censo_2020['ENTIDAD'].apply(lambda x: f'{x:02d}')
censo_2020['MUN'] = censo_2020['MUN'].apply(lambda x: f'{x:03d}')
censo_2020['LOC'] = censo_2020['LOC'].apply(lambda x: f'{x:04d}')
censo_2020['AGEB'] = censo_2020['AGEB'].apply(lambda x: str(x).zfill(4))

# Concatenar las columnas en una sola columna "CVEGEO"
censo_2020['CVEGEO'] = censo_2020['ENTIDAD'] + censo_2020['MUN'] + censo_2020['LOC'] + censo_2020['AGEB']
censo_2020_filtered = censo_2020[censo_2020["MZA"]==0][["CVEGEO", "POBTOT"]]

# %%
agebs_2020

# %%
gdl_2020 = agebs_2020.loc[(agebs_2020.CVE_ENT == "14") & (agebs_2020.CVE_MUN == "039") & (agebs_2020.Ambito == "Urbana")].copy()
gdl_2020 = gdl_2020.merge(censo_2020_filtered, on='CVEGEO', how='left')
gdl_2020 = gdl_2020.rename(columns={'POBTOT': 'pobtot'}).reset_index(drop = True)
gdl_2020.dropna(inplace = True)
gdl_2020
# Out:
#             CVEGEO CVE_ENT CVE_MUN CVE_LOC CVE_AGEB  Ambito  \
# 0    1403900012696      14     039    0001     2696  Urbana
# 1    1403900014207      14     039    0001     4207  Urbana
# 2    1403900013020      14     039    0001     3020  Urbana
# 3    1403900014194      14     039    0001     4194  Urbana
# 4    1403900015243      14     039    0001     5243  Urbana
# ..             ...     ...     ...     ...      ...     ...
# 437  1403900014584      14     039    0001     4584  Urbana
# 438  1403900010562      14     039    0001     0562  Urbana
# 439  1403900014508      14     039    0001     4508  Urbana
# 440  140390001507A      14     039    0001     507A  Urbana
# 441  1403900015065      14     039    0001     5065  Urbana
#
#                                               geometry  pobtot
# 0    POLYGON ((2357150.791 959790.056, 2357114.481 ...    6406
# 1    POLYGON ((2367389.408 966302.223, 2367366.228 ...    4817
# ...

# %%
mid_2020 = agebs_2020.loc[(agebs_2020.CVE_ENT == "31") & (agebs_2020.CVE_MUN == "050") & (agebs_2020.Ambito == "Urbana")].copy()
mid_2020 = mid_2020.merge(censo_2020_filtered, on='CVEGEO', how='left')
mid_2020 = mid_2020.rename(columns={'POBTOT': 'pobtot'}).reset_index(drop=True)
mid_2020.dropna(inplace = True)
mid_2020
# Out:
#             CVEGEO CVE_ENT CVE_MUN CVE_LOC CVE_AGEB  Ambito  \
# 0    3105000015329      31     050    0001     5329  Urbana
# 1    3105000012466      31     050    0001     2466  Urbana
# 2    310500001249A      31     050    0001     249A  Urbana
# 3    3105000015827      31     050    0001     5827  Urbana
# 4    3105000014706      31     050    0001     4706  Urbana
# ..             ...     ...     ...     ...      ...     ...
# 521  3105000017039      31     050    0001     7039  Urbana
# 522  3105000014049      31     050    0001     4049  Urbana
# 523  3105000010864      31     050    0001     0864  Urbana
# 524  310500001085A      31     050    0001     085A  Urbana
# 525  3105000010879      31     050    0001     0879  Urbana
#
#                                               geometry  pobtot
# 0    POLYGON ((3779478.623 1047307.492, 3779480.973...    2199
# 1    POLYGON ((3777875.435 1056949.722, 3777947.632...    3049
# ...

# %%
mty_2020 = agebs_2020.loc[(agebs_2020.CVE_ENT == "19") & (agebs_2020.CVE_MUN == "039") & (agebs_2020.Ambito == "Urbana")].copy()
mty_2020 = mty_2020.merge(censo_2020_filtered, on='CVEGEO', how='left')
mty_2020 = mty_2020.rename(columns={'POBTOT': 'pobtot'}).reset_index(drop=True)
mty_2020.dropna(inplace = True)
mty_2020
# Out:
#             CVEGEO CVE_ENT CVE_MUN CVE_LOC CVE_AGEB  Ambito  \
# 0    1903900012400      19     039    0001     2400  Urbana
# 1    1903900013470      19     039    0001     3470  Urbana
# 2    1903900014303      19     039    0001     4303  Urbana
# 3    1903900014657      19     039    0001     4657  Urbana
# 4    1903900013485      19     039    0001     3485  Urbana
# ..             ...     ...     ...     ...      ...     ...
# 486  1903900015212      19     039    0001     5212  Urbana
# 487  1903900015513      19     039    0001     5513  Urbana
# 488  1903900013201      19     039    0001     3201  Urbana
# 489  1903900010014      19     039    0001     0014  Urbana
# 490  1903900014958      19     039    0001     4958  Urbana
#
#                                               geometry  pobtot
# 0    POLYGON ((2663249.026 1525529.990, 2663211.044...    4517
# 1    POLYGON ((2661573.280 1522037.516, 2661613.392...    3973
# ...

# %%
def reproyectar_ageb_to_mesh(agebs_1990, malla_geo):
    # Realizar la intersección espacial entre las geometrías
    intersection = gpd.sjoin(malla_geo, agebs_1990, how="inner", predicate='intersects')
    
    
    # Calcular la proporción de área compartida
    intersection['area_intersection'] = intersection.geometry.area
    intersection['prop_area'] = intersection['area_intersection'] / intersection.geometry.area
    
    # Proyectar la población
    intersection['poblacion_proyectada'] = intersection['prop_area'] * intersection['pobtot']
    
    # Agrupar por celda de la malla y sumar la población proyectada
    poblacion_por_malla = intersection.groupby('codigo')['poblacion_proyectada'].sum().reset_index()
    
    # Realizar la fusión entre poblacion_por_malla y el GeoDataFrame de la intersección
    poblacion_por_malla_con_geometria = poblacion_por_malla.merge(intersection[['codigo', 'geometry']], on='codigo', how='left')
    poblacion_por_malla_con_geometria = gpd.GeoDataFrame(poblacion_por_malla_con_geometria, geometry='geometry')
    # Graficar la geometría con la población utilizando una escala de color
    fig, ax = plt.subplots(1, 1, figsize=(10, 8))
    poblacion_por_malla_con_geometria.plot(column='poblacion_proyectada', edgecolor='black', cmap='YlGnBu', 
                                           legend=True, ax=ax, legend_kwds={'label': "Población Proyectada"})
    
    # Superponer las geometrías de las AGEBs encima del gráfico existente
    agebs_1990.plot(ax=ax, alpha=0.5, edgecolor='white')
    
    plt.title('Población Proyectada por Celda de Malla con AGEBs')
    plt.show()

# %%
mid_2000.crs
# Out:
# <Projected CRS: PROJCS["MEXICO_ITRF_2008_LCC",GEOGCS["MEXICO_ITRF_ ...>
# Name: MEXICO_ITRF_2008_LCC
# Axis Info [cartesian]:
# - [east]: Easting (metre)
# - [north]: Northing (metre)
# Area of Use:
# - undefined
# Coordinate Operation:
# - name: unnamed
# - method: Lambert Conic Conformal (2SP)
# Datum: International Terrestrial Reference Frame 2008
# - Ellipsoid: GRS 1980
# - Prime Meridian: Greenwich

# %%
reproyectar_ageb_to_mesh(mid_2000, malla_geo)

# %%
reproyectar_ageb_to_mesh(mid_2010, malla_geo)
# Out:
# /var/folders/nk/_xd63xrx3wn4jgn4d0v2_5y80000gn/T/ipykernel_56093/3068958675.py:7: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   intersection['area_intersection'] = intersection.geometry.area
# /var/folders/nk/_xd63xrx3wn4jgn4d0v2_5y80000gn/T/ipykernel_56093/3068958675.py:8: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   intersection['prop_area'] = intersection['area_intersection'] / intersection.geometry.area

# %%
reproyectar_ageb_to_mesh(mid_2020, malla_geo)
# Out:
# /var/folders/nk/_xd63xrx3wn4jgn4d0v2_5y80000gn/T/ipykernel_56093/3068958675.py:7: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   intersection['area_intersection'] = intersection.geometry.area
# /var/folders/nk/_xd63xrx3wn4jgn4d0v2_5y80000gn/T/ipykernel_56093/3068958675.py:8: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   intersection['prop_area'] = intersection['area_intersection'] / intersection.geometry.area

# %%
reproyectar_ageb_to_mesh(mty_2000, malla_geo)

# %%
reproyectar_ageb_to_mesh(mty_2010, malla_geo)
# Out:
# /var/folders/nk/_xd63xrx3wn4jgn4d0v2_5y80000gn/T/ipykernel_56093/3068958675.py:7: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   intersection['area_intersection'] = intersection.geometry.area
# /var/folders/nk/_xd63xrx3wn4jgn4d0v2_5y80000gn/T/ipykernel_56093/3068958675.py:8: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   intersection['prop_area'] = intersection['area_intersection'] / intersection.geometry.area

# %%
reproyectar_ageb_to_mesh(mty_2020, malla_geo)
# Out:
# /var/folders/nk/_xd63xrx3wn4jgn4d0v2_5y80000gn/T/ipykernel_56093/3068958675.py:7: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   intersection['area_intersection'] = intersection.geometry.area
# /var/folders/nk/_xd63xrx3wn4jgn4d0v2_5y80000gn/T/ipykernel_56093/3068958675.py:8: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   intersection['prop_area'] = intersection['area_intersection'] / intersection.geometry.area

# %%
reproyectar_ageb_to_mesh(gdl_2000, malla_geo)

# %%
reproyectar_ageb_to_mesh(gdl_2010, malla_geo)
# Out:
# /var/folders/nk/_xd63xrx3wn4jgn4d0v2_5y80000gn/T/ipykernel_56093/3068958675.py:7: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   intersection['area_intersection'] = intersection.geometry.area
# /var/folders/nk/_xd63xrx3wn4jgn4d0v2_5y80000gn/T/ipykernel_56093/3068958675.py:8: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   intersection['prop_area'] = intersection['area_intersection'] / intersection.geometry.area

# %%
reproyectar_ageb_to_mesh(gdl_2020, malla_geo)

# %%
gdl_2020
# Out:
#             CVEGEO CVE_ENT CVE_MUN CVE_LOC CVE_AGEB  Ambito  \
# 0    1403900012696      14     039    0001     2696  Urbana
# 1    1403900014207      14     039    0001     4207  Urbana
# 2    1403900013020      14     039    0001     3020  Urbana
# 3    1403900014194      14     039    0001     4194  Urbana
# 4    1403900015243      14     039    0001     5243  Urbana
# ..             ...     ...     ...     ...      ...     ...
# 436  1403900013321      14     039    0001     3321  Urbana
# 437  1403900014584      14     039    0001     4584  Urbana
# 439  1403900014508      14     039    0001     4508  Urbana
# 440  140390001507A      14     039    0001     507A  Urbana
# 441  1403900015065      14     039    0001     5065  Urbana
#
#                                               geometry  pobtot
# 0    POLYGON ((2357150.791 959790.056, 2357114.481 ...  6406.0
# 1    POLYGON ((2367389.408 966302.223, 2367366.228 ...  4817.0
# ...

# %%
hermosillo_2000_path = path_data + "hermosillo/AGEBS_2000/Censo_2000/Hermosillo_AGEBs_Poblacion_2000.shp"
hermosillo_2000  = gpd.read_file(hermosillo_2000_path)

# %%
hermosillo_2000
# Out:
#     CVE_EDO CVE_MUN    CVE_LOC        CVE_AGEB   AGEB NOM_EDO ABRE_EDO  \
# 0        26   26030  260300001  260300001270-6  270-6  SONORA      SON
# 1        26   26030  260300001  260300001644-6  644-6  SONORA      SON
# 2        26   26030  260300001  260300001331-4  331-4  SONORA      SON
# 3        26   26030  260300001  260300001620-0  620-0  SONORA      SON
# 4        26   26030  260300001  260300001622-A  622-A  SONORA      SON
# ..      ...     ...        ...             ...    ...     ...      ...
# 249      26   26030  260300001  260300001497-1  497-1  SONORA      SON
# 250      26   26030  260300001  260300001575-3  575-3  SONORA      SON
# 251      26   26030  260300001  260300001285-2  285-2  SONORA      SON
# 252      26   26030  260300001  260300001500-5  500-5  SONORA      SON
# 253      26   26030  260300001  260300001274-4  274-4  SONORA      SON
#
#         NOM_MUN     NOM_LOC    Z1  ...     I6     I7     I8     I9    I10  \
# ...

# %%
gdl_2020_test = agebs_2020.loc[(agebs_2020.CVE_ENT == "14") & (agebs_2020.CVE_MUN == "039") & (agebs_2020.Ambito == "Urbana")].copy()
gdl_2020_test.shape
# Out:
# (442, 7)

# %%
gdl_2020_test
# Out:
#               CVEGEO CVE_ENT CVE_MUN CVE_LOC CVE_AGEB  Ambito  \
# 23683  1403900012696      14     039    0001     2696  Urbana
# 23684  1403900014207      14     039    0001     4207  Urbana
# 23685  1403900013020      14     039    0001     3020  Urbana
# 23686  1403900014194      14     039    0001     4194  Urbana
# 23687  1403900015243      14     039    0001     5243  Urbana
# ...              ...     ...     ...     ...      ...     ...
# 24120  1403900014584      14     039    0001     4584  Urbana
# 24121  1403900010562      14     039    0001     0562  Urbana
# 24122  1403900014508      14     039    0001     4508  Urbana
# 24123  140390001507A      14     039    0001     507A  Urbana
# 24124  1403900015065      14     039    0001     5065  Urbana
#
#                                                 geometry
# 23683  POLYGON ((2357150.791 959790.056, 2357114.481 ...
# 23684  POLYGON ((2367389.408 966302.223, 2367366.228 ...
# ...

# %%
gdl_test = gdl_2020_test.merge(censo_2020_filtered, on='CVEGEO', how='left')
gdl_test[gdl_test.POBTOT.isnull()]
# Out:
#             CVEGEO CVE_ENT CVE_MUN CVE_LOC CVE_AGEB  Ambito  \
# 22   1403900010609      14     039    0001     0609  Urbana
# 27   1403900010670      14     039    0001     0670  Urbana
# 35   1403900010435      14     039    0001     0435  Urbana
# 37   1403900010882      14     039    0001     0882  Urbana
# 41   1403900010469      14     039    0001     0469  Urbana
# ..             ...     ...     ...     ...      ...     ...
# 395  1403900010473      14     039    0001     0473  Urbana
# 424  1403900010083      14     039    0001     0083  Urbana
# 427  1403900010030      14     039    0001     0030  Urbana
# 428  1403900010026      14     039    0001     0026  Urbana
# 438  1403900010562      14     039    0001     0562  Urbana
#
#                                               geometry  POBTOT
# 22   POLYGON ((2356464.575 965966.764, 2356504.145 ...     NaN
# 27   POLYGON ((2360204.978 965423.800, 2360201.977 ...     NaN
# ...

# %%
censo_2020.loc[(censo_2020.NOM_MUN == 'Guadalajara') & (censo_2020.NOM_LOC=="Total AGEB urbana")]
# Out:
#       ENTIDAD  NOM_ENT  MUN      NOM_MUN   LOC            NOM_LOC  AGEB  MZA  \
# 16177      14  Jalisco  039  Guadalajara  0001  Total AGEB urbana    26    0
# 16189      14  Jalisco  039  Guadalajara  0001  Total AGEB urbana    30    0
# 16244      14  Jalisco  039  Guadalajara  0001  Total AGEB urbana  005A    0
# 16265      14  Jalisco  039  Guadalajara  0001  Total AGEB urbana    64    0
# 16308      14  Jalisco  039  Guadalajara  0001  Total AGEB urbana    83    0
# ...       ...      ...  ...          ...   ...                ...   ...  ...
# 30283      14  Jalisco  039  Guadalajara  0001  Total AGEB urbana  5633    0
# 30285      14  Jalisco  039  Guadalajara  0001  Total AGEB urbana  5648    0
# 30309      14  Jalisco  039  Guadalajara  0001  Total AGEB urbana  5652    0
# 30340      14  Jalisco  039  Guadalajara  0001  Total AGEB urbana  5667    0
# 30371      14  Jalisco  039  Guadalajara  0001  Total AGEB urbana  5671    0
#
# ...

# %%
gdl_2020_test.plot()
# Out:
# <Axes: >
