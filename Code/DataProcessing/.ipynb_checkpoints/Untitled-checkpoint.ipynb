# %%
import pandas as pd
import geopandas as gpd

# %%
path_data_raw = "../../Sample_Data/Raw/"
file_agebs = "agebs_1990/AGEBs_90_TecMonty_aj/AGEB's_90_aj.shp"
file_census = "agebs_1990/AGEBs_90_TecMonty_aj/AGEB_Urbanos_1990_indicadores.csv"

# %%
agebs_1990 = gpd.read_file(path_data_raw+file)

# %%
agebs_1990.head()
# Out:
#    OBJECTID CVE_ENT CVE_MUN CVE_LOC CVE_AGEB  \
# 0         1      01     009    0001     0053
# 1         2      01     009    0001     0068
# 2         3      01     008    0001     015A
# 3         4      01     008    0001     0130
# 4         5      01     008    0001     0126
#
#                                             geometry
# 0  POLYGON ((2480877.300 1134784.103, 2480927.966...
# 1  POLYGON ((2482928.726 1134084.647, 2482941.429...
# 2  POLYGON ((2457986.836 1126048.649, 2458002.336...
# 3  POLYGON ((2457482.756 1125406.744, 2457784.406...
# 4  POLYGON ((2457664.278 1126449.007, 2457707.870...

# %%
agebs_1990[(agebs_1990.CVE_ENT == '31') & (agebs_1990.CVE_MUN == '050')].plot()
# Out:
# <Axes: >

# %%
agebs_1990.crs
# Out:
# <Projected CRS: PROJCS["MEXICO_ITRF_2008_LCC",GEOGCS["GCS_MEXICO_I ...>
# Name: MEXICO_ITRF_2008_LCC
# Axis Info [cartesian]:
# - [east]: Easting (metre)
# - [north]: Northing (metre)
# Area of Use:
# - undefined
# Coordinate Operation:
# - name: unnamed
# - method: Lambert Conic Conformal (2SP)
# Datum: International_Terrestrial_Reference_Frame_2008
# - Ellipsoid: GRS 1980
# - Prime Meridian: Greenwich

# %%
census_1990 = pd.read_csv(path_data_raw+file_census)
census_1990
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 census_1990 = pd.read_csv(path_data_raw+file_census)
#       2 census_1990
#
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/io/parsers/readers.py:912, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...
